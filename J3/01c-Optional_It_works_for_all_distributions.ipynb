# %% [markdown]
# # Math Reviews - Linear Algebra & Probability
#
# ## No it works for all the laws!

# %% [markdown]
# 0. Import usuals librairies: numpy, pandas, matplotlib.pyplot, seaborn

# %% [markdown]
# 1. This time generate simulations from other probability laws,
# e.g. binomial, Poisson, uniform, Student, gamma, Chi2 or other and
#  Repeat the same operations as in the previous exercise.

# %% [markdown]
# 2. Repeat the process for 3 or 4 common laws, what do you find?

# %% [markdown]
# 3. Do you think that this provides empirical proof of the central theorem
# limit

# %% [markdown]
# 4. For each law you have chosen, search for
# to understand what kind of random phenomena these laws describe.
