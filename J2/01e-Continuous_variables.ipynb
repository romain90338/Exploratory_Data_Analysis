# %% [markdown]
# # Multi variete representation of continuous variables
#
# For this part, we will use the following dataset: *sales_predictions.csv*.

# %% [markdown]
# 1. Import usual librairies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_predictions.csv")
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# 2. Use a _sample()_ to select 25 random entries from the dataset

# %%
df1 = df.sample(25)
df1.head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 359986   27.04.2013               3       28     8438       299.0
# 2620859  12.05.2015              28        3     9409       349.0
# 1758667  30.06.2014              17       57    21876       149.0
# 510376   22.05.2013               4       16     2437       799.0
# 2326144  18.01.2015              24       15    12512       499.0
#
#          item_cnt_day
# 359986            1.0
# 2620859           1.0
# 1758667           1.0
# 510376            1.0
# 2326144          -1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2597478  30.04.2015              27       42    14142       399.0
# 2517657  01.03.2015              26       54     8469       349.0
# 521272   08.05.2013               4       43    10660       999.0
# 122753   16.02.2013               1       42     1402      1499.0
# 2247386  18.12.2014              23       38    20774       499.0
#
#          item_cnt_day
# 2597478           1.0
# 2517657           1.0
# 521272            1.0
# 122753            1.0
# 2247386           1.0

# %% [markdown]
# 3. Using _relplot(),_ build a chart that will allow you to see the price evolution over time. What can you see?

# %%
sns.relplot(data=df1, x = "date", y = "item_price", kind="line", height=4, aspect=5)
plt.show()
# Out:
# c:\Users\Romain\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# résultat attendu

# %% [markdown]
# 4. Using the pd.to_datetime() function, convert your _date_ column to _datetime_.

# %%
df1["date"] = pd.to_datetime(df1["date"])
df["date"]
# Out:
# 0          02.01.2013
# 1          03.01.2013
# 2          05.01.2013
# 3          06.01.2013
# 4          15.01.2013
#               ...
# 2935844    10.10.2015
# 2935845    09.10.2015
# 2935846    14.10.2015
# 2935847    22.10.2015
# 2935848    03.10.2015
# Name: date, Length: 2935849, dtype: object

# %% [markdown]
# 5. Retry doing your visualization. What do you see?

# %%
sns.relplot(data=df1, x = "date", y = "item_price", kind="line", aspect=5, height=5)
plt.show()
# Out:
# c:\Users\Romain\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# résultat attendu
